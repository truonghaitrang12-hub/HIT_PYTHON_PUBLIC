# %% [markdown]
# # Buổi 2: Kiểu dữ liệu cơ bản, biến, biểu thức, nhập/xuất, Các cấu trúc điều khiển

# %% [markdown]
# ## I. Biến và biểu thức trong Python
# ### 1. Biến

# %% [markdown]
# **Biến** trong Python là các ô nhớ được đặt tên, dùng để lưu trữ các giá trị sẽ sử dụng trong chương trình. Python là ngôn ngữ động nên không cần khai báo kiểu trước.

# %% [markdown]
# ### 2. Cách khai báo biến

# %%
x = 10
name = "HIT"
website = "apple.com"

# %% [markdown]
# ### 3. Quy tắc đặt tên biến
#
# - Tên biến phân biệt chữ hoa và chữ thường (age khác Age)
# - Không bắt đầu bằng số
# - Không chứa ký tự đặc biệt (trừ _)
# - Không trùng với từ khóa của Python

# %%
age = 25
user_name = "Python Public"
pi = 3.14

# %% [markdown]
# ### 4. Gán giá trị cho nhiểu biến

# %%
# Biến có thể gán cùng một giá trị cho nhiều biến trong một dòng:
x = y = z = "HIT"
print(x)
print(y)
print(z)
# Out:
# HIT
# HIT
# HIT

# %%
# Python cho phép bạn gán giá trị cho nhiều biến trong một dòng:
x, y, z = "HIT", "Python", "Public 2026"
print(x)
print(y)
print(z)
# Out:
# HIT
# Python
# Public 2026

# %% [markdown]
# ***Lưu ý:*** Trong Python, chúng ta không thực sự gán giá trị cho các biến. Thay vào đó, Python cung cấp tham chiếu của đối tượng (giá trị) cho biến

# %% [markdown]
# ### 5. Hằng trong Python
#
# Trong Python, hằng thường được khai báo và gán giá
# trị cùng lúc, trong một mô-đun.

# %%
PI = 3.14
GRAVITY = 9.8

# %% [markdown]
# ***Lưu ý:***
# Trong Python, hằng thường được khai báo và gán giá trị cùng lúc trong một file riêng biệt(module) và được sử dụng trong file chính. Bên trong file riêng biệt này, các hằng được định nghĩa với tên hằng được viết hoa toàn bộ.

# %% [markdown]
# ## II. Kiểu dữ liệu của biến
#
# ### 1. Các kiểu dữ liệu
# Có nhiều kiểu dữ liệu khác nhau trong Python. Một số loại quan trọng được liệt kê dưới đây:
# - ***Kiểu văn bản:***
#     - **str:** chuỗi ký tự (e.g. "hello")
# - ***Kiểu số:***
#     - **int:** số nguyên (e.g 1, -5)
#     - **float:** số thực (e.g. 3.14, -0.5)
#     - **complex:** số phức (e.g. 3+5j, -5j)
#     - **bool:** giá trị đúng/sai (True/False)
# - ***Kiểu có cấu trúc:***
#     - **list, tuple, set, dict:** cấu trúc dữ liệu phức tạp (sẽ được học ở bài sau)

# %% [markdown]
# ### 2. Các thao tác kiểu dữ liệu

# %%
# Lấy kiểu dữ liệu của một biến: `type<<ten_bien>>`
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
# Kiểm tra một biến có thuộc một kiểu nào đó hay không
a = 10
print(isinstance(a, int))
# Out:
# True

# %% [markdown]
# ### 3. Chuyển đổi giữa các kiểu:
#
# Chúng ta có thể chuyển đổi giữa các kiểu dữ liệu khác nhau bằng cách sử dụng các hàm chuyển đổi kiểu khác nhau như: `int (), float (), str ()`, v.v.

# %%
a = 10
print(type(a))
b = float(a)
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### 6. Biểu thức
#
# #### Toán tử
#
# ##### 1. Toán tử số học
#
# | Toán tử | Ý nghĩa             | Ví dụ       |
# |---------|---------------------|-------------|
# | `+`     | Cộng                | `x + y`     |
# | `-`     | Trừ                 | `x - y`     |
# | `*`     | Nhân                | `x * y`     |
# | `/`     | Chia                | `x / y`     |
# | `//`    | Chia lấy phần nguyên| `x // y`    |
# | `%`     | Chia lấy dư         | `x % y`     |
# | `**`    | Lũy thừa            | `x ** y`    |
#
# ##### 2. Toán tử gán (Assignment Operators)
#
# | Toán tử | Ý nghĩa                    | Ví dụ        |
# |---------|----------------------------|--------------|
# | `=`     | Gán giá trị                | `x = 5`      |
# | `+=`    | Cộng rồi gán               | `x += 3`     |
# | `-=`    | Trừ rồi gán                | `x -= 2`     |
# | `*=`    | Nhân rồi gán               | `x *= 4`     |
# | `/=`    | Chia rồi gán               | `x /= 2`     |
# | `//=`   | Chia nguyên rồi gán        | `x //= 2`    |
# | `%=`    | Chia dư rồi gán            | `x %= 3`     |
# | `**=`   | Lũy thừa rồi gán           | `x **= 2`    |
#
# ##### 3. Toán tử so sánh (Comparison Operators)
#
# | Toán tử | Ý nghĩa                     | Ví dụ        |
# |---------|-----------------------------|--------------|
# | `==`    | So sánh bằng                | `x == y`     |
# | `!=`    | Khác nhau                   | `x != y`     |
# | `>`     | Lớn hơn                     | `x > y`      |
# | `<`     | Nhỏ hơn                     | `x < y`      |
# | `>=`    | Lớn hơn hoặc bằng           | `x >= y`     |
# | `<=`    | Nhỏ hơn hoặc bằng           | `x <= y`     |
#
# ##### 4. Toán tử logic (Logical Operators)
#
# | Toán tử | Ý nghĩa                     | Ví dụ             |
# |---------|-----------------------------|--------------------|
# | `and`   | Và – đúng khi cả hai đúng   | `x > 5 and x < 10` |
# | `or`    | Hoặc – đúng nếu một trong hai đúng | `x < 5 or x > 10` |
# | `not`   | Phủ định – đảo ngược kết quả | `not(x > 5)`      |
#
# ##### 5. Toán tử thành viên (Membership Operators)
#
# | Toán tử | Ý nghĩa                         | Ví dụ             |
# |---------|----------------------------------|--------------------|
# | `in`    | Kiểm tra phần tử có trong chuỗi, list... | `'a' in 'abc'`    |
# | `not in`| Kiểm tra phần tử không có trong  | `'z' not in 'abc'`|
#
# ##### 6. Toán tử nhận dạng (Identity Operators)
#
# | Toán tử | Ý nghĩa                                | Ví dụ         |
# |---------|-----------------------------------------|---------------|
# | `is`    | Kiểm tra 2 biến có cùng đối tượng không | `x is y`      |
# | `is not`| Kiểm tra 2 biến không cùng đối tượng    | `x is not y`  |
#
# ---
#
# ##### 7. Toán tử bit (Bitwise Operators)
#
# | Toán tử | Ý nghĩa               | Ví dụ    |
# |---------|------------------------|----------|
# | `&`     | AND                    | `x & y`  |
# | `\|`    | OR                     | `x \| y` |
# | `^`     | XOR                    | `x ^ y`  |
# | `~`     | NOT                    | `~x`     |
# | `<<`    | Dịch trái              | `x << 2` |
# | `>>`    | Dịch phải              | `x >> 2` |
#
# ---
#
#
# #### Toán hạng
# - **Hằng:** Gồm nhiều loại như hằng số, hằng chuỗi ký tự
# - **Biến:** Ta có thể sử dụng các biến trong biểu thức, giá trị của biến sẽ được sử dụng để tính toán giá trị của biểu thức.
# - **Hàm:** Các hàm trả về một giá trị cũng có thể được dùng tương tự một biến trong biểu thức

# %%
import math
a = 10
print(a + 2*math.sqrt(a))
# Out:
# 16.32455532033676

# %% [markdown]
# ## II. Nhập/ xuất

# %% [markdown]
# ### 1. Xuất dữ liệu:
# Sử dụng hàm: `print()`

# %%
print("Dữ liệu này được xuất ra màn hình")
# Out:
# Dữ liệu này được xuất ra màn hình

# %%
# Ta có thể xuất nhiều dữ liệu, ngăn cách nhau bởi dấu phảy. Ví dụ:
a = 5
print('a =', a)
# Out:
# a = 5

# %% [markdown]
# #### a. Cú pháp tổng quát:
# `print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)`
#
# Trong đó:
# - **'*'objects:** là các thành phần dữ liệu cần xuất.
# - **sep:** là ký tự ngăn cách giữa hai dữ liệu, mặc định là dấu cách.
# - **end:** Sau khi tất cả dữ liệu đã được in ra thiết bị xuất, ký tự được chỉ định trong
# - **end:** sẽ được in ra. Thông thường nó có thể là dấu xuống dòng ‘\n’.
# - **file:** Chỉ định thiết bị xuất (màn hình, file,...). Mặc định là sys.stdout (màn
# hình).

# %% [markdown]
# #### b. Định dạng dữ liệu xuất
#
# Ta có thể dùng ký hiệu giữ chỗ {} để xuất dữ liệu từ các biến, sử dụng phương thức format() như sau:

# %%
a = 5
print('a = {}'.format(a))
# Out:
# a = 5

# %%
b = 3
print(f"b = {b}")
# Out:
# b = 3

# %% [markdown]
# ### 2. Nhập dữ liệu
#
# Trong Python, chúng ta có hàm input() để cho phép điều này. Cú pháp cho input () là: `input([Câu thông báo])`

# %%
a = input()
a = int(input("nhap vao so a:"))
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 a = input()
# ----> 2 a = int(input("nhap vao so a:"))
#       3 print(a)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = input('Nhập một giá trị nguyên a:')

# %% [markdown]
# #### Nhập nhiều biến bằng một lệnh input

# %%
a, b = input().split()
print('a = ', a)
print('b = ', b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a, b = input().split()
#       2 print('a = ', a)
#       3 print('b = ', b)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %% [markdown]
# ## III. Cấu trúc điều khiển
# ### 1. Cấu trúc rẽ nhánh: *if*
# #### Cấu trúc *if:*
# ```
# if<condition>:
#     command
# ```
# #### Cấu trúc *if...else:*
# ```
# if<condition>:
#     command1
# else:
#     command2
# ```
# #### Cấu trúc *if...elif...else:*
# ```
# if<condition_1>:
#     command1
# elif<condition_2>:
#     command2
# else:
#     command3
# ```
# Trong đó:
# - `<condition>`, `<condition_1>`, `<condition_2>`: Là một biểu thức logic
# - `command1, command2, command3`: có thể là 1 lệnh, một cấu trúc điều khiển, một khối lệnh, hoặc khối cấu trúc điều khiển

# %%
x = 5
if x == 0:
    print("Số không")
elif x > 0:
    print("Số dương")
elif x < 0:
    print("Số âm")
else:
    print("Không phải số")
# Out:
# Số dương

# %% [markdown]
# ### 2. Vòng lặp for
# Vòng lặp for trong Python được sử dụng để lặp qua một chuỗi (ví dụ như danh sách, tuple, chuỗi ký tự) hoặc các đối tượng có thể lặp khác. Lặp theo một trình tự được gọi là duyệt.
#
# **Cú pháp:**
# ```
# for <variable> in <array>:
#     command
# ```
# **Trong đó:**
#  - **<Biến>** là một tên do ta tùy ý đặt. Biến sẽ lần lượt nhận từng giá trị trong
# <Dãy> và thực hiện Lệnh_lặp.
#  - **Lệnh_lặp:** có thể là 1 lệnh, một khối lệnh, một cấu trúc điều khiển hoặc một
# khối cấu trúc điều khiển

# %%
for x in (1, 2, 5):
    print(x)
# Out:
# 1
# 2
# 5

# %% [markdown]
# ### 3. Hàng range()
#
# Hàm range() thường được dùng kèm với lệnh for khi nó cho phép ta khởi tạo một dãy với nhiều dạng khác nhau:

# %%
 # `range(n)`: Khởi tạo các giá trị nguyên liên tiếp, từ 0 tới n - 1.
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# range(n, m): Khởi tạo các giá trị nguyên liên tiếp, từ n tới m - 1.
for x in range(11,3):
    print(x)

# %%
# range(start, stop, step) Khởi tạo một dãy các số nguyên từ start cho tới stop-1, nhưng với bước nhảy step.
for x in range(2, 10, 3):
    print(x)
# Out:
# 2
# 5
# 8

# %% [markdown]
# ### 4. Vòng lặp while
# Vòng lặp while trong Python được sử dụng để lặp qua một lệnh/ một khối lệnh miễn là biểu thức điều kiện là đúng. Chúng ta thường sử dụng vòng lặp này khi chúng ta không biết trước số lần lặp lại.
#
# **Cú pháp:**
# ```
# while <điều_kiện_lặp>:
#     <Lệnh_lặp>
# ```

# %%
x = 0
while x < 5:
    print(x)
    x += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## IV. Bài tập
#
# **Bài tập 1:**
# Nhập vào từ bàn phím hai số nguyên a, b. Tính và in ra màn hình tổng, hiệu, tích, thương của a và b với mỗi kết quả in trên 1 dòng; kết quả của thương là số thực có độ chính xác 3 chữ số hàng thập phân.
#
# **Bài tập 2:**
# Nhập vào tọa độ của hai điểm A(x1, y1) và B(x2, y2). Tính và in ra khoảng cách Euclidean giữa A và B theo công thức:
#
# $$d(A, B) = \sqrt{(x_1 - x_2)^2 + (y_1 - y_2)^2}$$
#
# **Bài tập 3:**
# Giải phương trình bậc 2 với các hệ số a, b, c nhập từ bàn phím.
#
# **Bài tập 4:**
# Nhập vào một số nguyên n cho tới khi $n \in [20, 30]$, nhập vào số thực x. Tính và in ra:
#
# $$P = 2022x^n + \frac{1}{x} + \frac{2}{x^2} + \dots + \frac{n}{x^n}$$
#
# **Bài tập 5:**
# Nhập vào một số nguyên dương n. kiểm tra xem n có phải là số nguyên tố hay
# không?
#
# **Bài tập 6:**
# Nhập vào một số nguyên n thuộc [100, 200]. Nếu dữ liệu nhập vào không thỏa mãn điều kiện đó, cho phép nhập lại cho tới khi thỏa mãn.
# Tìm một số nguyên dương là lũy thừa của 2, bé nhất, mà lớn hơn n
